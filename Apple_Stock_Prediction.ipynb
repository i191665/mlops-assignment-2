# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import date
import os

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Model Configuration

# %%
window_size = 7
batch_size = 32
shuffle_buffer_size = 1000

epochs = 100

# %% [markdown]
# ## API to Get Data

# %%
api_key = 'JTU5ZLRZQK4D1X0P'
ticker = 'AAPL'
interval = 'DAILY'
df = pd.read_csv(f'https://www.alphavantage.co/query?function=TIME_SERIES_{interval}_ADJUSTED&symbol={ticker}&outputsize=full&datatype=csv&apikey={api_key}')

# %% [markdown]
# ## Displaying Data

# %%
df
# Out:
#        timestamp    open     high     low   close  adjusted_close    volume  \
# 0     2023-03-20  155.07  157.820  154.15  157.40      157.400000  73641415
# 1     2023-03-17  156.08  156.740  154.28  155.00      155.000000  98944633
# 2     2023-03-16  152.16  156.460  151.64  155.85      155.850000  76254419
# 3     2023-03-15  151.19  153.245  149.92  152.99      152.990000  77167866
# 4     2023-03-14  151.28  153.400  150.10  152.59      152.590000  73695893
# ...          ...     ...      ...     ...     ...             ...       ...
# 5878  1999-11-05   84.62   88.370   84.00   88.31        0.670165   3721500
# 5879  1999-11-04   82.06   85.370   80.62   83.62        0.634574   3384700
# 5880  1999-11-03   81.62   83.250   81.00   81.50        0.618485   2932700
# 5881  1999-11-02   78.00   81.690   77.31   80.25        0.608999   3564600
# 5882  1999-11-01   80.00   80.690   77.37   77.62        0.589041   2487300
#
#       dividend_amount  split_coefficient
# 0                 0.0                1.0
# 1                 0.0                1.0
# 2                 0.0                1.0
# 3                 0.0                1.0
# 4                 0.0                1.0
# ...               ...                ...
# 5878              0.0                1.0
# 5879              0.0                1.0
# 5880              0.0                1.0
# 5881              0.0                1.0
# 5882              0.0                1.0
#
# [5883 rows x 9 columns]

# %% [markdown]
# ## Splitting Data Into Train and Test Set

# %%
train_df = df[(df['timestamp'] >= '2017-01-01') & (df['timestamp'] < '2022-01-01')]
train_df
# Out:
#        timestamp     open      high     low   close  adjusted_close    volume  \
# 304   2021-12-31  178.085  179.2300  177.26  177.57      176.054247  61661433
# 305   2021-12-30  179.470  180.5700  178.09  178.20      176.678869  59773014
# 306   2021-12-29  179.330  180.6300  178.14  179.38      177.848797  62348931
# 307   2021-12-28  180.160  181.3300  178.53  179.29      177.759565  79144339
# 308   2021-12-27  177.085  180.4200  177.07  180.33      178.790688  74919582
# ...          ...      ...       ...     ...     ...             ...       ...
# 1558  2017-01-09  117.950  119.4300  117.94  118.99       27.758430  33561948
# 1559  2017-01-06  116.780  118.1600  116.47  117.91       27.506484  31751900
# 1560  2017-01-05  115.920  116.8642  115.81  116.61       27.203215  22193587
# 1561  2017-01-04  115.850  116.5100  115.75  116.02       27.065577  21118116
# 1562  2017-01-03  115.800  116.3300  114.76  116.15       27.095904  28781865
#
#       dividend_amount  split_coefficient
# 304               0.0                1.0
# 305               0.0                1.0
# 306               0.0                1.0
# 307               0.0                1.0
# 308               0.0                1.0
# ...               ...                ...
# 1558              0.0                1.0
# 1559              0.0                1.0
# 1560              0.0                1.0
# 1561              0.0                1.0
# 1562              0.0                1.0
#
# [1259 rows x 9 columns]

# %%
test_df = df[(df['timestamp'] >= '2022-01-01') & (df['timestamp'] < '2023-01-01')]
test_df
# Out:
#       timestamp    open      high     low   close  adjusted_close     volume  \
# 53   2022-12-30  128.41  129.9500  127.43  129.93      129.732407   77034209
# 54   2022-12-29  127.99  130.4814  127.73  129.61      129.412894   75703710
# 55   2022-12-28  129.67  131.0275  125.87  126.04      125.848323   85438391
# 56   2022-12-27  131.38  131.4100  128.72  130.03      129.832255   69007830
# 57   2022-12-23  130.92  132.4150  129.64  131.86      131.659472   63814893
# ..          ...     ...       ...     ...     ...             ...        ...
# 299  2022-01-07  172.89  174.1400  171.03  172.17      170.700342   86709147
# 300  2022-01-06  172.70  175.3000  171.64  172.00      170.531793   96903955
# 301  2022-01-05  179.61  180.1700  174.64  174.92      173.426868   94537602
# 302  2022-01-04  182.63  182.9400  179.12  179.70      178.166065   99310438
# 303  2022-01-03  177.83  182.8800  177.71  182.01      180.456347  104701220
#
#      dividend_amount  split_coefficient
# 53            0.0000                1.0
# 54            0.0000                1.0
# 55            0.0000                1.0
# 56            0.0000                1.0
# 57            0.1667                1.0
# ..               ...                ...
# 299           0.0000                1.0
# 300           0.0000                1.0
# 301           0.0000                1.0
# 302           0.0000                1.0
# 303           0.0000                1.0
#
# [251 rows x 9 columns]

# %% [markdown]
# ## Plotting Train Set

# %%
train_series = train_df['close'].to_list()[::-1]
train_time = train_df['timestamp'].to_list()[::-1]
train_time = [date.fromisoformat(time) for time in train_time]

# %%
plt.figure(figsize=(12, 6))
plt.plot(train_time, train_series)
plt.show()

# %% [markdown]
# ## Plotting Test Set

# %%
test_series = test_df['close'].to_list()[::-1]
test_time = test_df['timestamp'].to_list()[::-1]
test_time = [date.fromisoformat(time) for time in test_time]

# %%
plt.figure(figsize=(8, 6))
plt.plot(test_time, test_series)
plt.show()

# %% [markdown]
# ## Generating Windowed (Time Series) Datasets

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer, do_shuffle=False):
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels 
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    if do_shuffle:
        dataset = dataset.shuffle(shuffle_buffer)
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    return dataset

# %%
train_dataset = windowed_dataset(train_series, window_size, batch_size, shuffle_buffer_size, do_shuffle=True)
test_dataset = windowed_dataset(test_series, window_size, batch_size, shuffle_buffer_size)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# ## Creating Model and Training It

# %%
model = keras.models.Sequential([
  keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation='relu',
                      padding='causal',
                      input_shape=[window_size, 1]),

  keras.layers.LSTM(64, return_sequences=True),
  keras.layers.LSTM(64),
  keras.layers.Dense(30, activation='relu'),
  keras.layers.Dense(10, activation='relu'),
  keras.layers.Dense(1),
])

model.compile(loss='mae', optimizer='adam')
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 13s 73ms/step - loss: 185.5589 - val_loss: 142.6110
# Epoch 2/100
# 40/40 [==============================] - 1s 16ms/step - loss: 168.8942 - val_loss: 119.2225
# Epoch 3/100
# 40/40 [==============================] - 1s 15ms/step - loss: 135.7498 - val_loss: 73.3409
# Epoch 4/100
# 40/40 [==============================] - 1s 16ms/step - loss: 77.4589 - val_loss: 10.8895
# Epoch 5/100
# 40/40 [==============================] - 1s 15ms/step - loss: 47.9033 - val_loss: 19.4964
# Epoch 6/100
# 40/40 [==============================] - 1s 28ms/step - loss: 47.4802 - val_loss: 17.2728
# Epoch 7/100
# 40/40 [==============================] - 1s 17ms/step - loss: 47.4779 - val_loss: 17.2453
# Epoch 8/100
# 40/40 [==============================] - 1s 15ms/step - loss: 47.5443 - val_loss: 17.7996
# Epoch 9/100
# 40/40 [==============================] - 1s 12ms/step - loss: 47.4577 - val_loss: 17.5109
# Epoch 10/100
# 40/40 [==============================] - 0s 8ms/step - loss: 47.4531 - val_loss: 17.8348
# Epoch 11/100
# 40/40 [==============================] - 0s 9ms/step - loss: 47.3898 - val_loss: 14.9849
# Epoch 12/100
# 40/40 [==============================] - 0s 9ms/step - loss: 45.6052 - val_loss: 10.4677
# Epoch 13/100
# 40/40 [==============================] - 0s 8ms/step - loss: 37.1275 - val_loss: 9.9380
# Epoch 14/100
# 40/40 [==============================] - 0s 9ms/step - loss: 23.3357 - val_loss: 12.8982
# Epoch 15/100
# 40/40 [==============================] - 0s 8ms/step - loss: 18.9453 - val_loss: 4.2471
# Epoch 16/100
# 40/40 [==============================] - 0s 8ms/step - loss: 13.7871 - val_loss: 4.6425
# Epoch 17/100
# 40/40 [==============================] - 0s 8ms/step - loss: 12.1024 - val_loss: 3.6384
# Epoch 18/100
# 40/40 [==============================] - 0s 9ms/step - loss: 8.3830 - val_loss: 6.3365
# Epoch 19/100
# 40/40 [==============================] - 0s 8ms/step - loss: 8.5196 - val_loss: 4.6582
# Epoch 20/100
# 40/40 [==============================] - 0s 9ms/step - loss: 7.6603 - val_loss: 6.6766
# Epoch 21/100
# 40/40 [==============================] - 0s 9ms/step - loss: 8.1428 - val_loss: 4.3688
# Epoch 22/100
# 40/40 [==============================] - 0s 8ms/step - loss: 6.5966 - val_loss: 7.3336
# Epoch 23/100
# 40/40 [==============================] - 0s 8ms/step - loss: 8.2441 - val_loss: 4.3017
# Epoch 24/100
# 40/40 [==============================] - 0s 9ms/step - loss: 7.3992 - val_loss: 3.6502
# Epoch 25/100
# 40/40 [==============================] - 0s 8ms/step - loss: 6.6604 - val_loss: 3.3733
# Epoch 26/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.7503 - val_loss: 3.4281
# Epoch 27/100
# 40/40 [==============================] - 0s 8ms/step - loss: 6.3972 - val_loss: 6.8599
# Epoch 28/100
# 40/40 [==============================] - 1s 11ms/step - loss: 7.7764 - val_loss: 4.5939
# Epoch 29/100
# 40/40 [==============================] - 1s 12ms/step - loss: 5.5735 - val_loss: 7.1265
# Epoch 30/100
# 40/40 [==============================] - 1s 12ms/step - loss: 6.4201 - val_loss: 3.3099
# Epoch 31/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.0821 - val_loss: 3.2483
# Epoch 32/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.2814 - val_loss: 4.0985
# Epoch 33/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.2543 - val_loss: 3.5767
# Epoch 34/100
# 40/40 [==============================] - 0s 9ms/step - loss: 6.7030 - val_loss: 6.3397
# Epoch 35/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.8034 - val_loss: 3.1521
# Epoch 36/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.0267 - val_loss: 3.0778
# Epoch 37/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.8328 - val_loss: 6.7760
# Epoch 38/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.9328 - val_loss: 3.1286
# Epoch 39/100
# 40/40 [==============================] - 0s 9ms/step - loss: 6.2072 - val_loss: 6.3438
# Epoch 40/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.1450 - val_loss: 6.9319
# Epoch 41/100
# 40/40 [==============================] - 0s 8ms/step - loss: 7.0034 - val_loss: 3.1303
# Epoch 42/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.2127 - val_loss: 3.3562
# Epoch 43/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.1923 - val_loss: 3.0738
# Epoch 44/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.3011 - val_loss: 3.1722
# Epoch 45/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.2070 - val_loss: 3.1168
# Epoch 46/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.1654 - val_loss: 3.4323
# Epoch 47/100
# 40/40 [==============================] - 0s 8ms/step - loss: 6.3116 - val_loss: 3.6876
# Epoch 48/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.9764 - val_loss: 4.0634
# Epoch 49/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.9377 - val_loss: 4.4235
# Epoch 50/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.4685 - val_loss: 4.4506
# Epoch 51/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.9373 - val_loss: 3.3236
# Epoch 52/100
# 40/40 [==============================] - 1s 12ms/step - loss: 3.8724 - val_loss: 3.0230
# Epoch 53/100
# 40/40 [==============================] - 1s 12ms/step - loss: 5.0332 - val_loss: 3.1338
# Epoch 54/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.7642 - val_loss: 3.5801
# Epoch 55/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.7741 - val_loss: 4.2429
# Epoch 56/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.6354 - val_loss: 3.3330
# Epoch 57/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.4099 - val_loss: 3.1763
# Epoch 58/100
# 40/40 [==============================] - 0s 8ms/step - loss: 6.2368 - val_loss: 3.9216
# Epoch 59/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.6767 - val_loss: 4.8081
# Epoch 60/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.3875 - val_loss: 5.1389
# Epoch 61/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.9274 - val_loss: 7.3769
# Epoch 62/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.1434 - val_loss: 3.1184
# Epoch 63/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.3788 - val_loss: 6.7544
# Epoch 64/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.6955 - val_loss: 2.9137
# Epoch 65/100
# 40/40 [==============================] - 0s 8ms/step - loss: 3.9640 - val_loss: 2.9126
# Epoch 66/100
# 40/40 [==============================] - 0s 8ms/step - loss: 3.8478 - val_loss: 3.2774
# Epoch 67/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.5836 - val_loss: 3.8047
# Epoch 68/100
# 40/40 [==============================] - 0s 8ms/step - loss: 5.0756 - val_loss: 3.0726
# Epoch 69/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.4776 - val_loss: 3.3158
# Epoch 70/100
# 40/40 [==============================] - 0s 8ms/step - loss: 3.6373 - val_loss: 2.9066
# Epoch 71/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.0067 - val_loss: 3.0047
# Epoch 72/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.0200 - val_loss: 3.1127
# Epoch 73/100
# 40/40 [==============================] - 0s 8ms/step - loss: 3.5338 - val_loss: 2.8136
# Epoch 74/100
# 40/40 [==============================] - 0s 8ms/step - loss: 3.8813 - val_loss: 5.5798
# Epoch 75/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.2017 - val_loss: 4.9280
# Epoch 76/100
# 40/40 [==============================] - 0s 10ms/step - loss: 4.6132 - val_loss: 3.4460
# Epoch 77/100
# 40/40 [==============================] - 1s 13ms/step - loss: 3.7388 - val_loss: 3.1425
# Epoch 78/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.3899 - val_loss: 5.7875
# Epoch 79/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.7176 - val_loss: 2.8926
# Epoch 80/100
# 40/40 [==============================] - 0s 10ms/step - loss: 4.8160 - val_loss: 2.9535
# Epoch 81/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.9558 - val_loss: 3.9080
# Epoch 82/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.0753 - val_loss: 4.3021
# Epoch 83/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.9948 - val_loss: 3.3671
# Epoch 84/100
# 40/40 [==============================] - 0s 8ms/step - loss: 3.6456 - val_loss: 3.8612
# Epoch 85/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.0415 - val_loss: 3.7543
# Epoch 86/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.6053 - val_loss: 2.7574
# Epoch 87/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.9428 - val_loss: 3.4136
# Epoch 88/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.0134 - val_loss: 3.6604
# Epoch 89/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.7589 - val_loss: 2.8348
# Epoch 90/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.1149 - val_loss: 2.7553
# Epoch 91/100
# 40/40 [==============================] - 0s 8ms/step - loss: 3.7884 - val_loss: 2.7414
# Epoch 92/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.4811 - val_loss: 3.8092
# Epoch 93/100
# 40/40 [==============================] - 0s 10ms/step - loss: 4.7936 - val_loss: 3.4899
# Epoch 94/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.7462 - val_loss: 6.1641
# Epoch 95/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.3257 - val_loss: 2.8115
# Epoch 96/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.2368 - val_loss: 3.7048
# Epoch 97/100
# 40/40 [==============================] - 0s 8ms/step - loss: 4.0062 - val_loss: 2.8753
# Epoch 98/100
# 40/40 [==============================] - 1s 11ms/step - loss: 3.5401 - val_loss: 4.3378
# Epoch 99/100
# 40/40 [==============================] - 1s 12ms/step - loss: 4.2507 - val_loss: 3.4286
# Epoch 100/100
# 40/40 [==============================] - 1s 11ms/step - loss: 3.9164 - val_loss: 2.7278

# %% [markdown]
# ## Generating Predictions and Plotting Them Against Test Data

# %%
forecast = model.predict(test_dataset)
# Out:
# 8/8 [==============================] - 1s 7ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(test_time[window_size:], test_series[window_size:], label='Original')
plt.plot(test_time[window_size:], forecast, label='Forecast')
plt.legend()
plt.xlabel('Days', fontsize=14)
plt.ylabel('Price in USD', fontsize=14)
plt.title(f'{ticker} Stock', fontsize=20)
plt.show()

# %% [markdown]
# ## Saving Model to Colab

# %%
model_name = 'stock_predictor.h5'
model.save(model_name)
